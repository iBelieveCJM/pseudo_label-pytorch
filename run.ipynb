# %%
from torch.utils.data import Dataset, DataLoader

# %%
from imp import reload
# Out:
# the total of data is 60000
# the number of sample:  2000
# Done.
# the number of sample:  58000
# Done.
# the number of sample:  10000
# Done.
# Train[1 / 500] loss: 2.31504, Acc: 9.40
# Train[2 / 500] loss: 2.30815, Acc: 10.30
# Train[3 / 500] loss: 2.30841, Acc: 9.45
# Train[4 / 500] loss: 2.30239, Acc: 10.70
# Train[5 / 500] loss: 2.30477, Acc: 10.20
# Train[6 / 500] loss: 2.30247, Acc: 11.65
# Train[7 / 500] loss: 2.29807, Acc: 12.20
# Train[8 / 500] loss: 2.29809, Acc: 11.80
# Train[9 / 500] loss: 2.29680, Acc: 12.15
# Train[10 / 500] loss: 2.29461, Acc: 11.70
# Train[11 / 500] loss: 2.29133, Acc: 12.80
# Train[12 / 500] loss: 2.29016, Acc: 12.25
# Train[13 / 500] loss: 2.28617, Acc: 14.60
# Train[14 / 500] loss: 2.28235, Acc: 15.15
# Train[15 / 500] loss: 2.27979, Acc: 16.80
# Train[16 / 500] loss: 2.27510, Acc: 16.25
# Train[17 / 500] loss: 2.27121, Acc: 17.85
# Train[18 / 500] loss: 2.26459, Acc: 17.15
# Train[19 / 500] loss: 2.26035, Acc: 19.70
# ...

# %%
#import example1
reload(example1)
example1.example1()
# Out:
# the total of data is 60000
# the number of sample:  2000
# Done.
# the number of sample:  58000
# Done.
# the number of sample:  10000
# Done.
# Train[1 / 200] loss: 1.33374, Acc: 56.50
# Train[2 / 200] loss: 0.38393, Acc: 86.65
# Train[3 / 200] loss: 0.25893, Acc: 92.40
# Train[4 / 200] loss: 0.19173, Acc: 93.80
# Train[5 / 200] loss: 0.14479, Acc: 95.40
# Train[6 / 200] loss: 0.12219, Acc: 96.15
# Train[7 / 200] loss: 0.08623, Acc: 97.50
# Train[8 / 200] loss: 0.06870, Acc: 98.20
# Train[9 / 200] loss: 0.05622, Acc: 98.50
# Train[10 / 200] loss: 0.04243, Acc: 99.05
# Train[11 / 200] loss: 0.03357, Acc: 98.85
# Train[12 / 200] loss: 0.02661, Acc: 99.25
# Train[13 / 200] loss: 0.02362, Acc: 99.40
# Train[14 / 200] loss: 0.01696, Acc: 99.65
# Train[15 / 200] loss: 0.01442, Acc: 99.65
# Train[16 / 200] loss: 0.00548, Acc: 100.00
# Train[17 / 200] loss: 0.00300, Acc: 100.00
# Train[18 / 200] loss: 0.00190, Acc: 100.00
# Train[19 / 200] loss: 0.00156, Acc: 100.00
# ...

# %%
import example2
reload(example2)
example2.example2()
# Out:
# the total of data is 60000
# the number of sample:  7120
# Done.
# the number of sample:  52880
# Done.
# the number of sample:  10000
# Done.

# %%
356*2
# Out:
# 712
